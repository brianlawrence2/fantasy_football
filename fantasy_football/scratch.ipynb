# %%
import pandas as pd
import duckdb
import sqlalchemy

# %load_ext sql

# %%
draft_picks = pd.read_parquet('../data/draft_picks/draft_picks.parquet')
play_by_play = pd.read_parquet('../data/play_by_play/play_by_play_2021.parquet')
players = pd.read_parquet('../data/players/players.parquet')
weekly_rosters = pd.read_parquet('../data/weekly_rosters/roster_weekly_2022.parquet')

# %%
draft_picks.head()
# Out:
#    season  round  pick team gsis_id pfr_player_id    cfb_player_id  \
# 0    1980      1     1  DET    None      SimsBi00     billy-sims-1
# 1    1980      1     2  NYJ    None      JoneLa00      lam-jones-1
# 2    1980      1     3  CIN    None      MunoAn00             None
# 3    1980      1     4  GNB    None      ClarBr23    bruce-clark-1
# 4    1980      1     5  BAL    None      DickCu00  curtis-dickey-1
#
#   pfr_player_name    hof position  ... pass_ints rush_atts rush_yards  \
# 0      Billy Sims  False       RB  ...       0.0    1131.0     5106.0
# 1       Lam Jones  False       WR  ...       0.0       9.0       17.0
# 2   Anthony Munoz   True        T  ...       0.0       0.0        0.0
# 3     Bruce Clark  False       DE  ...       0.0       0.0        0.0
# 4   Curtis Dickey  False       RB  ...       0.0     937.0     4019.0
#
#    rush_tds  receptions  rec_yards  rec_tds  def_solo_tackles  def_ints  \
# ...

# %%
play_by_play.head()
# Out:
#    play_id          game_id old_game_id home_team away_team season_type  week  \
# 0      1.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG     1
# 1     40.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG     1
# 2     55.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG     1
# 3     76.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG     1
# 4    100.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG     1
#
#   posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0    None         None    None  ...           0.0                   1.0
# 1     TEN         home     ARI  ...           0.0                   1.0
# 2     TEN         home     ARI  ...           0.0                   1.0
# 3     TEN         home     ARI  ...           0.0                   1.0
# 4     TEN         home     ARI  ...           0.0                   1.0
#
# ...

# %%
players.head()
# Out:
#   status   display_name first_name last_name     esb_id     gsis_id  \
# 0    RET  'Omar Ellison      'Omar   Ellison  ELL711319  00-0004866
# 1    ACT    A.J. Arcuri       A.J.    Arcuri       None  00-0037845
# 2    RES     A.J. Bouye   Arlandus     Bouye  BOU651714  00-0030228
# 3    ACT     A.J. Brown     Arthur     Brown  BRO413223  00-0035676
# 4    ACT      A.J. Cann      Aaron      Cann  CAN364949  00-0032255
#
#    birth_date     college_name position_group position  ...  rookie_year  \
# 0        None             None             WR       WR  ...          NaN
# 1        None             None             OL        T  ...       2022.0
# 2  1991-08-16  Central Florida             DB       CB  ...       2013.0
# 3  1997-06-30      Mississippi             WR       WR  ...       2019.0
# 4  1991-10-03   South Carolina             OL        G  ...       2015.0
#
#   draft_club draft_number            college_conference  \
# 0       None          NaN                          None
# ...

# %%
weekly_rosters.head()
# Out:
#    season game_type  week  jersey_number last_name football_name first_name  \
# 0    2022       REG     1           14.0       Lee          Andy       Andy
# 1    2022       REG     1            5.0    Prater          Matt       Matt
# 2    2022       REG     1           12.0     McCoy          Colt     Daniel
# 3    2022       REG     1           18.0     Green          A.J.     Adriel
# 4    2022       REG     1           99.0      Watt          J.J.     Justin
#
#   depth_chart_position  entry_year  rookie_year  ... display_name  short_name  \
# 0                    P        2004         2004  ...     Andy Lee       A.Lee
# 1                    K        2006         2006  ...  Matt Prater    M.Prater
# 2                   QB        2010         2010  ...   Colt McCoy     C.McCoy
# 3                   WR        2011         2011  ...   A.J. Green     A.Green
# 4                   DE        2011         2011  ...    J.J. Watt      J.Watt
#
# ...

# %%
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///../data/duckdb/fantasy_football.duckdb

# %%
# %%sql
# SELECT
#     schema_name,
#     function_name
# FROM duckdb_functions()
# ORDER BY ALL DESC
# LIMIT 5
# Out:
#   schema_name              function_name
# 0  pg_catalog          shobj_description
# 1  pg_catalog                  pg_typeof
# 2  pg_catalog         pg_type_is_visible
# 3  pg_catalog  pg_ts_template_is_visible
# 4  pg_catalog    pg_ts_parser_is_visible

# %%
# %%sql
#
# CREATE TABLE draft_picks AS SELECT * FROM draft_picks
# CREATE TABLE play_by_play AS SELECT * FROM play_by_play
# CREATE TABLE players AS SELECT * FROM players
# CREATE TABLE weekly_rosters AS SELECT * FROM weekly_rosters
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/fantasy-football-IEv2X29m-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/Library/Caches/pypoetry/virtualenvs/fantasy-football-IEv2X29m-py3.10/lib/python3.10/site-packages/duckdb_engine/__init__.py:186, in Dialect.do_execute(self, cursor, statement, parameters, context)
#     179 def do_execute(
#     180     self,
#     181     cursor: ConnectionWrapper,
#    (...)
#     184     context: PGExecutionContext,
#     185 ) -> None:
# ...

# %%
# %%sql
# SELECT *
# FROM draft_picks
# LIMIT 10
# Out:
#    season  round  pick team gsis_id pfr_player_id    cfb_player_id  \
# 0    1980      1     1  DET    None      SimsBi00     billy-sims-1
# 1    1980      1     2  NYJ    None      JoneLa00      lam-jones-1
# 2    1980      1     3  CIN    None      MunoAn00             None
# 3    1980      1     4  GNB    None      ClarBr23    bruce-clark-1
# 4    1980      1     5  BAL    None      DickCu00  curtis-dickey-1
# 5    1980      1     6  STL    None      GreeCu21   curtis-greer-1
# 6    1980      1     7  ATL    None      MillJu00  junior-miller-1
# 7    1980      1     8  NYG    None      HaynMa00    mark-haynes-1
# 8    1980      1     9  MIN    None      MartDo21             None
# 9    1980      1    10  SEA    None      GreeJa01    jacob-green-2
#
#   pfr_player_name    hof position  ... pass_ints rush_atts rush_yards  \
# 0      Billy Sims  False       RB  ...       0.0    1131.0     5106.0
# 1       Lam Jones  False       WR  ...       0.0       9.0       17.0
# ...

# %%
con.close()

# %%
import os
from pathlib import Path

path = Path('../data')

for file in os.listdir(path/'play_by_play'):
    print(file)
# Out:
# play_by_play_2014.parquet
# play_by_play_2004.parquet
# play_by_play_1999.parquet
# play_by_play_2005.parquet
# play_by_play_2015.parquet
# play_by_play_2021.parquet
# play_by_play_2017.parquet
# play_by_play_2007.parquet
# play_by_play_2006.parquet
# play_by_play_2016.parquet
# play_by_play_2020.parquet
# play_by_play_2013.parquet
# play_by_play_2003.parquet
# play_by_play_2002.parquet
# play_by_play_2012.parquet
# play_by_play_2010.parquet
# play_by_play_2000.parquet
# play_by_play_2009.parquet
# play_by_play_2019.parquet
# play_by_play_2018.parquet
# play_by_play_2008.parquet
# play_by_play_2001.parquet
# play_by_play_2011.parquet

# %%
# %%sql
# select
#     game_id,
#     home_team,
#     away_team,
#     posteam,
#     defteam,
#     play_type,
#     count(*) plays
# from play_by_play
# group by 1,2,3,4,5,6
# limit 10
# Out:
#  * duckdb:///../data/duckdb/fantasy_football.duckdb
# Done.
# [('2014_01_BUF_CHI', 'CHI', 'BUF', 'CHI', 'BUF', 'pass', 51),
#  ('2014_01_BUF_CHI', 'CHI', 'BUF', 'CHI', 'BUF', 'kickoff', 6),
#  ('2014_01_CIN_BAL', 'BAL', 'CIN', 'CIN', 'BAL', 'field_goal', 6),
#  ('2014_01_CIN_BAL', 'BAL', 'CIN', 'BAL', 'CIN', 'punt', 4),
#  ('2014_01_CIN_BAL', 'BAL', 'CIN', 'BAL', 'CIN', 'extra_point', 1),
#  ('2014_01_CLE_PIT', 'PIT', 'CLE', None, None, None, 5),
#  ('2014_01_CLE_PIT', 'PIT', 'CLE', 'CLE', 'PIT', 'field_goal', 2),
#  ('2014_01_GB_SEA', 'SEA', 'GB', 'SEA', 'GB', 'extra_point', 4),
#  ('2014_01_GB_SEA', 'SEA', 'GB', 'SEA', 'GB', 'punt', 2),
#  ('2014_01_IND_DEN', 'DEN', 'IND', 'DEN', 'IND', 'qb_kneel', 4)]
